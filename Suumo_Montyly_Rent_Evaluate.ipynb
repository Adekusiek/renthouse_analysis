# %%
import pandas as pd
from sklearn.externals import joblib

df = pd.read_csv("suumo_treated.csv", sep='\t', encoding='utf-16', index_col=0)
clf = joblib.load('suumo_rent_monthly_rent.pkl')

df = df.drop([29926, 69267, 69266, 199848, 76041])
df = df.drop(df.index[df['築年数'] == 99])
df = df.dropna()

ward = pd.get_dummies(df['区'])

df = pd.merge(df, ward, left_index=True, right_index=True)

Y_true = df['賃料月額']
df.drop(['マンション名','区','路線', '駅', '賃料','管理費','敷金','礼金','保証金','敷引,償却', '賃料月額', '初期費用', '年間費用'], axis=1, inplace=True)  
data = df

# %%
delta = clf.predict(data) - Y_true
delta.name = '予想賃料月額'
delta.head()
# Out:
# 0    2885.000000
# 1   -5900.041667
# 2    1030.000000
# 3   -3745.000000
# 4    2415.000000
# Name: 予想年間費用, dtype: float64

# %%
df = pd.read_csv("suumo_treated.csv", sep='\t', encoding='utf-16', index_col=0)
df = df.drop([29926, 69267, 69266, 199848, 76041])
df = df.drop(df.index[df['築年数'] == 99])
df = df.dropna()

df = pd.concat([df, delta], axis=1)
#df = df[df['駅']=='牛込神楽坂駅']
df = df.sort_values(by='予想賃料月額', ascending=False)
df.head(40)
# Out:
#                               マンション名    区  間取り  間取りDK_LDK  間取りK  間取りS  築年数  \
# 200092                    ガーデンハウス壱番館  江戸川    1          0     1     0   16
# 1845                        ベラージュおとわ  千代田    2          1     0     0   11
# 1847         東京メトロ半蔵門線 神保町駅 4階建 築11年  千代田    2          1     0     0   11
# 27747                            渡邊邸   文京    3          1     0     1   31
# 1846                        ベラージュおとわ  千代田    2          1     0     0   11
# 1848         東京メトロ半蔵門線 神保町駅 4階建 築11年  千代田    2          1     0     0   11
# 128401                    杉並区和泉３丁目戸建   杉並    6          1     0     1   19
# 12913                    ウィンザーハウス元麻布    港    3          1     0     0   16
# 98119          東急田園都市線 三軒茶屋駅 9階建 築7年  世田谷    1          0     1     0    7
# 98115                      フェニシア三軒茶屋  世田谷    1          0     1     0    7
# 14751                       エリーマンション   新宿    1          0     0     0   48
# 103224                等々力一丁目　一時貸し戸建て  世田谷    8          1     0     1   44
# 12819    東京メトロ日比谷線 広尾駅 地下1地上2階建 築38年    港    3          1     0     0   38
# 12893   東京メトロ南北線 麻布十番駅 地下1地上7階建 築15年    港    4          1     0     1   15
# 12863                テラス乃木坂　メゾネットタイプ    港    4          1     0     1   13
# 195326              第２パークサイドマンション・ハル   葛飾    1          0     0     0   29
# 12870                          麻布マナー    港    4          1     0     0   15
# 11849       東京メトロ南北線 麻布十番駅 10階建 築15年    港    2          1     0     0   15
# 112809                       本町３丁目住宅   中野    7          1     0     1   22
# 103475                          代沢戸建  世田谷    5          1     0     0   35
# 62879             京急本線 立会川駅 5階建 築29年   品川    4          1     0     0   29
# 50272              メイクスデザイン住吉アジールコート   江東    1          0     1     0    4
# 50275              メイクスデザイン住吉アジールコート   江東    1          0     1     0    4
# 50271              メイクスデザイン住吉アジールコート   江東    1          0     1     0    4
# 34556           ｍｏｄｅｒｎｏ　ｔｏｒｒｅ　ｓｈｏ－ｔｏ   渋谷    1          1     0     0   10
# 103474      京王井の頭線 池ノ上駅 地下1地上2階建 築8年  世田谷    3          1     0     0    8
# 45337          都営浅草線 本所吾妻橋駅 3階建 築11年   墨田    4          1     0     1   11
# 2020                    ロイパルパインレジデンス  千代田    4          1     0     0   12
# 82521              京急空港線 糀谷駅 3階建 築7年   大田    3          1     0     1    7
# 62922                 ＯＨＳＡＫＩ　ＭＡＹＦＡＩＲ   品川    4          1     0     0   37
# 12124     都営大江戸線 六本木駅 地下1地上14階建 築18年    港    4          1     0     1   18
# 103473           京王井の頭線 池ノ上駅 2階建 築8年  世田谷    3          1     0     0    8
# 103469                       代沢１丁目貸家  世田谷    3          1     0     0    8
# 103470                       代沢１丁目貸家  世田谷    3          1     0     0    8
# 103471                       代沢１丁目貸家  世田谷    3          1     0     0    8
# 12843    東京メトロ南北線 麻布十番駅 地下1地上4階建 築9年    港    3          1     0     0    9
# 68206                   パークキューブ目黒タワー   目黒    2          1     0     0   10
# 68214       ＪＲ山手線 目黒駅 地下2地上22階建 築10年   目黒    2          1     0     0   10
# 11845                    オリンピアード麻布霞坂    港    4          1     0     1   18
# 12849                       ベルメゾン南青山    港    3          1     0     0   16
#
#         建物高さ   階    専有面積      ...             賃料    管理費       敷金      礼金  保証金  \
# 200092     3   2  228.65      ...          60000   5000    60000   60000    0
# 1845       4   4   68.56      ...         250000      0   250000  250000    0
# 1847       4   4   68.56      ...         250000      0   250000  250000    0
# 27747      3   1  279.66      ...         700000      0  1400000  700000    0
# 1846       4   4   68.56      ...         270000      0   270000  270000    0
# 1848       4   4   68.56      ...         270000      0   270000  270000    0
# 128401     4   1  243.25      ...         450000      0   900000  450000    0
# 12913      6   5  263.38      ...        1450000      0  5800000       0    0
# 98119      9   4   25.92      ...         100000   6000   100000  100000    0
# 98115      9   4   25.92      ...         100000   6000   100000  100000    0
# 14751      6   2  224.00      ...          70000   3000    70000   70000    0
# 103224     2   1  264.00      ...         250000      0   500000  250000    0
# 12819      3   2  210.00      ...         720000      0  1440000  720000    0
# 12893      8   2  241.12      ...        1170000      0  4680000       0    0
# 12863      4   1  231.52      ...         850000      0  2550000       0    0
# 195326     3   1  304.43      ...         710000      0  1970000       0    0
# 12870      7   2  241.12      ...        1170000      0  4680000       0    0
# 11849     10  10   90.73      ...         390000      0   790000  790000    0
# 112809     3   2  297.00      ...         600000      0   600000  600000    0
# 103475     3   1  259.40      ...         370000      0   750000  370000    0
# 62879      5   4  195.51      ...         330000  20000   660000       0    0
# 50272      9   5   26.04      ...          80000  10000        0   80000    0
# 50275      9   5   26.04      ...          80000  12000        0   80000    0
# 50271      9   5   26.04      ...          80000  12000        0   80000    0
