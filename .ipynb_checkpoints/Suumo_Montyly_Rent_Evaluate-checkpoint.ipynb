# %%
import pandas as pd
from sklearn.externals import joblib

df = pd.read_csv("suumo_treated.csv", sep='\t', encoding='utf-16', index_col=0)
clf = joblib.load('suumo_rent.pkl')

df = df.drop([29926, 69267, 69266, 199848, 76041])
df = df.drop(df.index[df['築年数'] == 99])
df = df.dropna()

ward = pd.get_dummies(df['区'])

df = pd.merge(df, ward, left_index=True, right_index=True)

Y_true = df['年間費用']
df.drop(['マンション名','区','路線', '駅', '賃料','管理費','敷金','礼金','保証金','敷引,償却', '賃料月額', '初期費用', '年間費用'], axis=1, inplace=True)  
data = df

# %%
delta = clf.predict(data) - Y_true
delta.name = '予想年間費用'
delta.head()
# Out:
# 0    37360.000000
# 1   -56410.619048
# 2    83995.200000
# 3     4944.800000
# 4    49236.000000
# Name: 予想年間費用, dtype: float64

# %%
df = pd.read_csv("suumo_treated.csv", sep='\t', encoding='utf-16', index_col=0)
df = df.drop([29926, 69267, 69266, 199848, 76041])
df = df.drop(df.index[df['築年数'] == 99])
df = df.dropna()

df = pd.concat([df, delta], axis=1)
df = df[df['駅']=='牛込神楽坂駅']
df = df.sort_values(by='予想年間費用', ascending=False)
df.head(40)
# Out:
#                             マンション名   区  間取り  間取りDK_LDK  間取りK  間取りS  築年数  建物高さ  \
# 21621                        ルネ神楽坂  新宿    1          1     0     0   11    18
# 22846  都営大江戸線 牛込神楽坂駅 地下1地上5階建 築10年  新宿    3          1     0     0   10     6
# 16108       都営大江戸線 牛込神楽坂駅 4階建 築54年  新宿    1          1     0     0   54     4
# 21052               デュオ・スカーラ神楽坂タワー  新宿    1          1     0     0   14    15
# 16891                 スカイコート神楽坂壱番館  新宿    1          0     1     0   15    13
# 22661       都営大江戸線 牛込神楽坂駅 4階建 築27年  新宿    1          1     0     0   27     4
# 17245                 ステージファースト神楽坂  新宿    1          0     1     0   14    10
# 17648                  スカイコート牛込神楽坂  新宿    1          0     1     0   10     5
# 20459       都営大江戸線 牛込神楽坂駅 9階建 築49年  新宿    1          1     0     0   49     9
# 12983                          村上荘  新宿    1          0     1     0   45     2
# 22061      都営大江戸線 牛込神楽坂駅 12階建 築15年  新宿    1          1     0     0   15    12
# 21405      都営大江戸線 牛込神楽坂駅 11階建 築35年  新宿    3          1     0     0   35    11
# 21404                     ハイホーム市ヶ谷  新宿    3          1     0     0   35    11
# 21403                     ハイホーム市ヶ谷  新宿    3          1     0     0   35    11
# 13740                        ヴィラＫ２  新宿    1          0     0     0   28     4
# 16419                      メイゾン神楽坂  新宿    2          0     1     0   49     5
# 14077                       FLAT-I  新宿    1          0     1     0   29     3
# 21663       都営大江戸線 牛込神楽坂駅 4階建 築21年  新宿    1          1     0     0   21     4
# 17795                      神楽坂フラッツ  新宿    1          0     0     0    8    11
# 22583       都営大江戸線 牛込神楽坂駅 6階建 築29年  新宿    1          1     0     0   29     6
# 22577                    カルパティア市ヶ谷  新宿    1          1     0     0   29     6
# 22688                   アーバンコート市ヶ谷  新宿    2          1     0     0   25     5
# 22712       都営大江戸線 牛込神楽坂駅 5階建 築24年  新宿    2          1     0     0   24     5
# 18574                         石黒ビル  新宿    2          1     0     0   31     7
# 15341       都営大江戸線 牛込神楽坂駅 5階建 築47年  新宿    1          0     0     0   47     5
# 16897      都営大江戸線 牛込神楽坂駅 13階建 築16年  新宿    1          0     1     0   16    13
# 16332       都営大江戸線 牛込神楽坂駅 4階建 築12年  新宿    1          0     1     0   12     4
# 16337              トーシンフェニックス牛込神楽坂  新宿    1          0     1     0   12     4
# 22689                   アーバンコート市ヶ谷  新宿    2          1     0     0   25     5
# 22690                   アーバンコート市ヶ谷  新宿    2          1     0     0   25     5
# 16689             Ｓ・Ｈａｒａｉｋａｔａｍａｃｈｉ  新宿    1          0     1     0   24     2
# 20940        都営大江戸線 牛込神楽坂駅 5階建 築9年  新宿    1          0     0     0    9     5
# 16894                 スカイコート神楽坂壱番館  新宿    1          0     1     0   15    13
# 18932                    コンフォリア神楽坂  新宿    1          0     0     0   11     6
# 16893                 スカイコート神楽坂壱番館  新宿    1          0     1     0   15    13
# 21137       都営大江戸線 牛込神楽坂駅 2階建 築70年  新宿    2          1     0     0   70     2
# 14874                     ニューライフ牛込  新宿    1          0     0     0   19     4
# 14638       都営大江戸線 牛込神楽坂駅 2階建 築19年  新宿    1          0     1     0   19     2
# 16898      都営大江戸線 牛込神楽坂駅 13階建 築16年  新宿    1          0     1     0   16    13
# 16902      都営大江戸線 牛込神楽坂駅 13階建 築16年  新宿    1          0     1     0   16    13
#
#         階    専有面積      ...            賃料    管理費       敷金      礼金  保証金  敷引,償却  \
# 21621  11   41.11      ...        140000  10000   140000  140000    0      0
# 22846   1  145.90      ...        700000      0  2100000       0    0      0
# 16108   2   36.00      ...         80000      0    80000   80000    0      0
# 21052   8   45.69      ...        160000  10000   160000       0    0      0
# 16891   6   21.17      ...         70000  10000    70000   70000    0      0
# 22661   4   77.76      ...        250000      0   250000  250000    0      0
# 17245   2   21.75      ...         90000      0    90000   90000    0      0
# 17648   2   21.35      ...         80000  10500        0   80000    0      0
# 20459   4   52.11      ...        120000      0   250000  120000    0      0
# 12983   2   21.45      ...         40000      0    40000   90000    0      0
# 22061   8   45.69      ...        160000  10000   160000       0    0      0
# 21405   4   60.75      ...        130000  10000   270000       0    0      0
# 21404   4   60.75      ...        130000  10000   270000       0    0      0
# 21403   4   60.75      ...        130000  10000   270000       0    0      0
# 13740   1   18.85      ...         60000      0    60000       0    0      0
# 16419   4   32.00      ...         80000      0    80000   80000    0      0
# 14077   2   20.10      ...         60000      0    60000   60000    0      0
# 21663   4   55.38      ...        150000   5000   150000  150000    0      0
# 17795   3   25.10      ...         80000   6000    80000   80000    0      0
# 22583   5   76.60      ...        240000  15000   240000  240000    0      0
